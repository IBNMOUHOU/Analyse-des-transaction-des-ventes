# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Sales.csv')

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %%
df = df.drop(['Day','Month','Year'],axis=1)

# %%
df.head()
# Out:
#          Date  Customer_Age       Age_Group Customer_Gender    Country  \
# 0  2013-11-26            19     Youth (<25)               M     Canada
# 1  2015-11-26            19     Youth (<25)               M     Canada
# 2  2014-03-23            49  Adults (35-64)               M  Australia
# 3  2016-03-23            49  Adults (35-64)               M  Australia
# 4  2014-05-15            47  Adults (35-64)               F  Australia
#
#               State Product_Category Sub_Category              Product  \
# 0  British Columbia      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 1  British Columbia      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 2   New South Wales      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 3   New South Wales      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 4   New South Wales      Accessories   Bike Racks  Hitch Rack - 4-Bike
#
#    Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  Revenue
# ...

# %%
df.describe()
# Out:
#         Customer_Age  Order_Quantity      Unit_Cost     Unit_Price  \
# count  113036.000000   113036.000000  113036.000000  113036.000000
# mean       35.919212       11.901660     267.296366     452.938427
# std        11.021936        9.561857     549.835483     922.071219
# min        17.000000        1.000000       1.000000       2.000000
# 25%        28.000000        2.000000       2.000000       5.000000
# 50%        35.000000       10.000000       9.000000      24.000000
# 75%        43.000000       20.000000      42.000000      70.000000
# max        87.000000       32.000000    2171.000000    3578.000000
#
#               Profit           Cost        Revenue
# count  113036.000000  113036.000000  113036.000000
# mean      285.051665     469.318695     754.370360
# std       453.887443     884.866118    1309.094674
# min       -30.000000       1.000000       2.000000
# 25%        29.000000      28.000000      63.000000
# 50%       101.000000     108.000000     223.000000
# ...

# %%
sns.countplot(df,x='Product_Category',hue='Customer_Gender')
# Out:
# <Axes: xlabel='Product_Category', ylabel='count'>

# %%
plt.figure(figsize=(12,10),dpi=200)
sns.scatterplot(df,x='Age_Group',y='Revenue')
# Out:
# <Axes: xlabel='Age_Group', ylabel='Revenue'>

# %%
df[(df['Revenue']> 50000) & (df['Age_Group'] == 'Adults (35-64)')]
#pour avoir les deux points dans la figure ci-dessus
# Out:
#               Date  Customer_Age       Age_Group Customer_Gender    Country  \
# 112072  2013-07-24            52  Adults (35-64)               M  Australia
# 112073  2015-07-24            52  Adults (35-64)               M  Australia
#
#              State Product_Category Sub_Category                  Product  \
# 112072  Queensland         Clothing        Vests  Touring-1000 Yellow, 50
# 112073  Queensland         Clothing        Vests  Touring-1000 Yellow, 50
#
#         Order_Quantity  Unit_Cost  Unit_Price  Profit   Cost  Revenue
# 112072              27       1482        2384   14055  40014    54069
# 112073              29       1482        2384   15096  42978    58074

# %%
sns.barplot(df,x='Country',y='Revenue',hue='Customer_Gender')
plt.legend(loc=(1.05,1))

# %%
sns.catplot(x='Customer_Gender',y='Product_Category',data=df,kind='box')

# %%
df.head(3)
# Out:
#          Date  Customer_Age       Age_Group Customer_Gender    Country  \
# 0  2013-11-26            19     Youth (<25)               M     Canada
# 1  2015-11-26            19     Youth (<25)               M     Canada
# 2  2014-03-23            49  Adults (35-64)               M  Australia
#
#               State Product_Category Sub_Category              Product  \
# 0  British Columbia      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 1  British Columbia      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 2   New South Wales      Accessories   Bike Racks  Hitch Rack - 4-Bike
#
#    Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  Revenue
# 0               8         45         120     590   360      950
# 1               8         45         120     590   360      950
# 2              23         45         120    1366  1035     2401

# %%
plt.figure(figsize=(12,12),dpi=200)
sns.catplot(x='Customer_Gender',y='Product_Category',data=df,kind='box',row='Age_Group',col='Country')
